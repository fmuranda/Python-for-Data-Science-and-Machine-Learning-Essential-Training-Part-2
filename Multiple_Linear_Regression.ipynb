# %% [markdown]
# <a href="https://colab.research.google.com/github/fmuranda/Python-for-Data-Science-and-Machine-Learning-Essential-Training-Part-2/blob/main/Multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# import the Counter class from the collections module, which will be used for counting
from collections import Counter

# %%
address = 'enrollment_forecast.csv'

# %%
enroll = pd.read_csv(address)
enroll.columns = ['year', 'roll','unem','hgrad','inc']
enroll.head()
# Out:
#    year  roll  unem  hgrad   inc
# 0     1  5501   8.1   9552  1923
# 1     2  5945   7.0   9680  1961
# 2     3  6629   7.3   9731  1979
# 3     4  7556   7.5  11666  2030
# 4     5  8716   7.0  14675  2112

# %%
sns.pairplot (enroll)
