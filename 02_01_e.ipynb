# %% [markdown]
# <a href="https://colab.research.google.com/github/fmuranda/Python-for-Data-Science-and-Machine-Learning-Essential-Training-Part-2/blob/main/02_01_e.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple linear regression

# %%
# !pip install numpy

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

from pylab import rcParams

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10, 8

# %%
rooms = 2*np.random.randn(100,1)+3
rooms[0:10]
# Out:
# array([[1.63753087],
#        [3.58281945],
#        [5.77785522],
#        [4.56165027],
#        [2.60088667],
#        [4.41862718],
#        [5.43444411],
#        [0.47645691],
#        [1.90161755],
#        [3.47709401]])

# %%
price = 265 + 6*rooms +abs(np.random.randn(100, 1))
price[0:10]
# Out:
# array([[274.88721955],
#        [287.11589554],
#        [300.51083144],
#        [292.400992  ],
#        [281.40430625],
#        [292.13039823],
#        [297.83051616],
#        [269.05491127],
#        [276.67960583],
#        [286.29295382]])

# %%
plt.plot(rooms,price, 'r^')
plt.xlabel('# of Rooms, 2024 Average')
plt.ylabel('2024 Average Home Price, $1000s USD')
plt.show()

# %%
X = rooms
y = price

LinReg = LinearRegression()
LinReg.fit(X,y)
print(LinReg.intercept_, LinReg.coef_)
# Out:
# [265.81220315] [[5.99996521]]

# %% [markdown]
# *Simple Algebra*
# - y = mx + b
# - b = intercept = 265.97
#
# *Estimated Coefficients*
# - LinReg.coef_ = [5.95] Estimated coefficients for the terms in the linear regression problem.

# %%
print(LinReg.score(X,y))
# Out:
# 0.9969867025457708
